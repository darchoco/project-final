# %%
import pandas as pd

# %%
df = pd.read_csv("lyrics.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#    Unnamed: 0      genre            artist                song  \
# 0           0  Christian    Glory Revealed       By His Wounds
# 1           1  Christian    Caedmon's Call      God of Wonders
# 2           2  Christian           MercyMe  I Can Only Imagine
# 3           3  Christian       Aaron Shust    My Savior My God
# 4           4  Christian  Michael W. Smith             Breathe
#
#                                               lyrics  wordcount  \
# 0  glory revealed by his wounds he was pierced fo...        205
# 1  lord of heaven and earth lord of all creation ...        217
# 2  i can only imagine what it will be like when i...        275
# 3  i am not skilled to understand what god has wi...        371
# 4  this is the air i breathe this is the air i br...        198
#
#    nostopwordcount  positivewordcount  positivepercents  negativewordcount  \
# 0               79                  7              8.86                 16
# ...

# %%
#only taking the lyrics from the dataframe
lyrics_df = df['lyrics']
lyrics_df.head()
# Out:
# 0    glory revealed by his wounds he was pierced fo...
# 1    lord of heaven and earth lord of all creation ...
# 2    i can only imagine what it will be like when i...
# 3    i am not skilled to understand what god has wi...
# 4    this is the air i breathe this is the air i br...
# Name: lyrics, dtype: object

# %%
# printing tokenized list of all the lyrics we have pulled
from Models import worddata
for line in lyrics_df:
    print (worddata.word_calcs(line).nostopwordlist())
# Out:
# ['glory', 'revealed', 'wounds', 'pierced', 'transgressions', 'crushed', 'sins', 'punishment', 'brought', 'us', 'peace', 'upon', 'wounds', 'wounds', 'healed', 'pierced', 'transgressions', 'crushed', 'sins', 'punishment', 'brought', 'us', 'peace', 'upon', 'wounds', 'wounds', 'healed', 'healed', 'sacrifice', 'life', 'gave', 'healed', 'paid', 'price', 'grace', 'saved', 'saved', 'pierced', 'transgressions', 'crushed', 'sins', 'punishment', 'brought', 'us', 'peace', 'upon', 'wounds', 'wounds', 'healed', 'healed', 'sacrifice', 'life', 'gave', 'healed', 'paid', 'price', 'grace', 'saved', 'saved', 'pierced', 'transgressions', 'crushed', 'sins', 'punishment', 'brought', 'us', 'peace', 'upon', 'wounds', 'wounds', 'healed', 'wounds', 'wounds', 'wash', 'away', 'sin', 'nothing', 'blood', 'jesus']
# ...

# %%
## pulling only the genre and the lyrics from the original dataframe
lyrics_test_df = df[['genre','lyrics']]
lyrics_test_df.head()
# Out:
#        genre                                             lyrics
# 0  Christian  glory revealed by his wounds he was pierced fo...
# 1  Christian  lord of heaven and earth lord of all creation ...
# 2  Christian  i can only imagine what it will be like when i...
# 3  Christian  i am not skilled to understand what god has wi...
# 4  Christian  this is the air i breathe this is the air i br...

# %%
# Pivoting the table so that genre becomes the row names and lyrics are the columns for it's genre

lyrics_test_df_pivot = lyrics_test_df.pivot(columns='genre', values='lyrics')
lyrics_test_df_pivot.head()
# Out:
# genre                                          Christian Country Hip Hop/Rap  \
# 0      glory revealed by his wounds he was pierced fo...     NaN         NaN
# 1      lord of heaven and earth lord of all creation ...     NaN         NaN
# 2      i can only imagine what it will be like when i...     NaN         NaN
# 3      i am not skilled to understand what god has wi...     NaN         NaN
# 4      this is the air i breathe this is the air i br...     NaN         NaN
#
# genre Rhythm and Blues Rock
# 0                  NaN  NaN
# 1                  NaN  NaN
# 2                  NaN  NaN
# 3                  NaN  NaN
# 4                  NaN  NaN

# %% [markdown]
# # Christian Genre

# %%
# Making a new dataframe with only the Christian genre from our pivoted dataframe above and dropping any null values
lyrics_test_df_christian = lyrics_test_df_pivot[['Christian']].dropna()
lyrics_test_df_christian.head()

## this prints out the whole dataframe so you can view up to 999 rows
# with pd.option_context('display.max_rows', 999):
#     print (lyrics_test_df_christian)
# Out:
# genre                                          Christian
# 0      glory revealed by his wounds he was pierced fo...
# 1      lord of heaven and earth lord of all creation ...
# 2      i can only imagine what it will be like when i...
# 3      i am not skilled to understand what god has wi...
# 4      this is the air i breathe this is the air i br...

# %%
# Combining our lists into one big list from the Christian genre list

from Models import worddata

christian_list = []


for word in lyrics_test_df_christian['Christian']:
    words = worddata.word_calcs(word).nostopwordlist()
    for item in words: 
        christian_list.append(item)
# print(christian_list)  


wordlist = []
wordfreq = []

for word in christian_list:
    i= 0
    wordcount= 0
    wordlist.append(word)
    wordfreq.append(christian_list.count(word))

print(wordlist)
print(wordfreq)
# Out:
# ['glory', 'revealed', 'wounds', 'pierced', 'transgressions', 'crushed', 'sins', 'punishment', 'brought', 'us', 'peace', 'upon', 'wounds', 'wounds', 'healed', 'pierced', 'transgressions', 'crushed', 'sins', 'punishment', 'brought', 'us', 'peace', 'upon', 'wounds', 'wounds', 'healed', 'healed', 'sacrifice', 'life', 'gave', 'healed', 'paid', 'price', 'grace', 'saved', 'saved', 'pierced', 'transgressions', 'crushed', 'sins', 'punishment', 'brought', 'us', 'peace', 'upon', 'wounds', 'wounds', 'healed', 'healed', 'sacrifice', 'life', 'gave', 'healed', 'paid', 'price', 'grace', 'saved', 'saved', 'pierced', 'transgressions', 'crushed', 'sins', 'punishment', 'brought', 'us', 'peace', 'upon', 'wounds', 'wounds', 'healed', 'wounds', 'wounds', 'wash', 'away', 'sin', 'nothing', 'blood', 'jesus', 'lord', 'heaven', 'earth', 'lord', 'creation', 'lord', 'heaven', 'earth', 'lord', 'creation', 'water', 'earth', 'sky', 'heavens', 'tabernacle', 'glory', 'lord', 'high', 'god', 'wonders', 'beyond', 'galaxy
# ...

# %%
christian_word_df = pd.DataFrame(wordlist, columns = ["Word"])
christian_word_df["Frequency"] = wordfreq
christian_word_df = christian_word_df.drop_duplicates()
print(christian_word_df)
# Out:
#                 Word  Frequency
# 0              glory         54
# 1           revealed          1
# 2             wounds         13
# 3            pierced          5
# 4     transgressions          4
# ...              ...        ...
# 9507            burn          1
# 9511            weve          1
# 9512          longed          1
# 9555           paint          1
# 9623         hallelu          4
#
# [1409 rows x 2 columns]

# %%
christian_word_df_sorted = christian_word_df.sort_values(by='Frequency', ascending=False)
christian_word_df_sorted.head(10)

# %%
import matplotlib.pyplot as plt
import numpy as np


country_songs_length = len(lyrics_test_df_country)

# Create an array that contains the frequency count of the top 10 words for the song's genre
word = ["god", "im", "lord", "love", "know", "let", "ive", "heart", "life", "like"]
frequency = [219/country_songs_length, 156/country_songs_length, 139/country_songs_length, 123/country_songs_length, 111/country_songs_length, 94/country_songs_length, 91/country_songs_length, 90/country_songs_length, 89/country_songs_length, 85/country_songs_length]

x_axis = np.arange(0, len(word))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)

plt.title("Avg Word Frequency for Genre: Christian")
plt.xlabel("Word in Song")
plt.ylabel("Word Frequency")

plt.xlim(-0.75, len(word)-.25)
plt.ylim(0, max(frequency) + .5)

plt.bar(x_axis, frequency, facecolor="red", alpha=0.75, align="center")
plt.xticks(tick_locations, word)

plt.savefig('static/christian_barchart.svg')
plt.savefig('static/christian_barchart.png')

# %% [markdown]
# # Country Genre

# %%
# Making a new dataframe with only the Country genre from our pivoted dataframe above and dropping any null values

lyrics_test_df_country = lyrics_test_df_pivot[['Country']].dropna()
lyrics_test_df_country.head()

## this prints out the whole dataframe so you can view up to 999 rows
# with pd.option_context('display.max_rows', 999):
#     print (lyrics_test_df_country)
# Out:
# genre                                            Country
# 93     i was standing by the window on a dark and clo...
# 94     blue moon of kentucky keep on shinin' shine on...
# 95     hear that lonesome whippoorwill he sounds too ...
# 96     hank cochran make the world go away and get it...
# 97     he said i'll love you till i die she told him ...

# %%
# Combining our lists into one big list from the country genre list

from Models import worddata

country_list = []


for word in lyrics_test_df_country['Country']:
    words = worddata.word_calcs(word).nostopwordlist()
    for item in words: 
        country_list.append(item)
# print(country_list)  


wordlist = []
wordfreq = []

for word in country_list:
    i= 0
    wordcount= 0
    wordlist.append(word)
    wordfreq.append(country_list.count(word))

print(wordlist)
print(wordfreq)
# Out:
# ['standing', 'window', 'dark', 'cloudy', 'day', 'saw', 'hearse', 'come', 'rolling', 'carry', 'mother', 'away', 'circle', 'unbroken', 'lord', "'s", 'better', 'home', 'awaiting', 'sky', 'lord', 'sky', 'lord', 'told', 'undertaker', 'undertaker', 'please', 'drive', 'slow', 'body', 'holding', 'lord', 'lord', 'hate', 'see', 'go', 'circle', 'unbroken', 'lord', "'s", 'better', 'home', 'awaiting', 'sky', 'lord', 'sky', 'followed', 'close', 'behind', 'tried', 'hold', 'brave', 'could', 'hide', 'sorrow', 'laid', 'grave', 'circle', 'unbroken', 'lord', "'s", 'better', 'home', 'awaiting', 'sky', 'lord', 'sky', 'went', 'home', 'lord', 'home', 'lonesome', 'yes', 'mother', 'gone', 'brothers', 'sisters', 'cryin', "'", 'home', 'sit', 'alone', 'circle', 'unbroken', 'lord', "'s", 'better', 'home', 'awaiting', 'sky', 'lord', 'sky', 'blue', 'moon', 'kentucky', 'keep', 'shinin', "'", 'shine', 'one', 'whose', 'gone', 'proved', 'untrue', 'blue', 'moon', 'kentucky', 'keep', 'shinin', "'", 'shine', 'one', 'whose
# ...

# %%
import pandas as pd
country_word_df = pd.DataFrame(wordlist, columns = ["Word"])
country_word_df["Frequency"] = wordfreq
country_word_df = country_word_df.drop_duplicates()
print(country_word_df)
# Out:
#             Word  Frequency
# 0       standing          1
# 1         window          4
# 2           dark          4
# 3         cloudy          1
# 4            day         43
# ...          ...        ...
# 9740      choice          1
# 9750     depends          1
# 9751    whatever          1
# 9782  temptation          2
# 9818         sin          1
#
# [2022 rows x 2 columns]

# %%
country_word_df = country_word_df[country_word_df.Word !='\'' ]
country_word_df = country_word_df[country_word_df.Word !='\'s' ]
country_word_df = country_word_df[country_word_df.Word !='n\'t' ]
country_word_df = country_word_df[country_word_df.Word !='\'m' ]
country_word_df = country_word_df[country_word_df.Word !='\'ve' ]
country_word_df = country_word_df[country_word_df.Word !='\'ll' ]
country_word_df = country_word_df[country_word_df.Word !='\'re' ]

country_word_df_sorted = country_word_df.sort_values(by='Frequency', ascending=False)
country_word_df_sorted.head(10)
# Out:
#       Word  Frequency
# 123   love        187
# 117  night         78
# 461    man         76
# 173   like         75
# 333   know         71
# 365  heart         66
# 673   well         63
# 35      go         60
# 34     see         57
# 156   time         57

# %%
import matplotlib.pyplot as plt
import numpy as np

country_songs_length = len(lyrics_test_df_country)

# Create an array that contains the frequency count of the top 10 words for the song's genre
word = ["love", "night", "man", "like", "know", "heart", "well", "go", "see", "time"]
frequency = [187/country_songs_length, 78/country_songs_length, 76/country_songs_length, 75/country_songs_length, 71/country_songs_length, 66/country_songs_length, 63/country_songs_length, 60/country_songs_length, 57/country_songs_length, 57/country_songs_length]

x_axis = np.arange(0, len(word))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)

plt.title("Avg Word Frequency for Genre: Country")
plt.xlabel("Word in Song")
plt.ylabel("Word Frequency")

plt.xlim(-0.75, len(word)-.25)
plt.ylim(0, max(frequency) + .5)

plt.bar(x_axis, frequency, facecolor="red", alpha=0.75, align="center")
plt.xticks(tick_locations, word)

plt.savefig('country_barchart.svg')
plt.savefig('country_barchart.png')

# %% [markdown]
# # Rap Genre

# %%
# Making a new dataframe with only the Country genre from our pivoted dataframe above and dropping any null values
lyrics_test_df_rap = lyrics_test_df_pivot[['Hip Hop/Rap']].dropna()
lyrics_test_df_rap.head()

## this prints out the whole dataframe so you can view up to 999 rows
# with pd.option_context('display.max_rows', 999):
#     print (lyrics_test_df_rap)
# Out:
# genre                                        Hip Hop/Rap
# 273    backstroke lover always hidin' 'neath the cove...
# 274    intro fuck all y'all hoes get a grip motherfuc...
# 275    one two three and to the fo' snoop doggy dogg ...
# 276    you are now about to witness the strength of s...
# 277    ah push it ah push it oooh baby baby baby baby...

# %%
# Combining our lists into one big list from the rap genre list

from Models import worddata

rap_list = []

for word in lyrics_test_df_rap['Hip Hop/Rap']:
    words = worddata.word_calcs(word).nostopwordlist()
    for item in words: 
        rap_list.append(item)
# print(rap_list)  

wordlist = []
wordfreq = []

for word in rap_list:
    i= 0
    wordcount= 0
    wordlist.append(word)
    wordfreq.append(rap_list.count(word))

print(wordlist)
print(wordfreq)
# Out:
# ['backstroke', 'lover', 'always', 'hidin', "'", "'neath", 'covers', 'till', 'talked', 'daddy', 'say', 'said', '``', 'ai', "n't", 'seen', 'nothin', "'", 'till', "'re", 'muffin', "'re", 'sure', 'achangin', "'", 'ways', "''", 'met', 'cheerleader', 'real', 'young', 'bleeder', 'oh', 'times', 'could', 'reminisce', "'cause", 'best', 'things', 'lovin', "'", 'sister', 'cousin', 'started', 'little', 'kiss', 'like', 'seesaw', 'swingin', "'", 'boys', 'school', 'feet', 'flyin', "'", 'air', 'singin', "'", '``', 'hey', 'diddle', 'diddle', "''", 'kitty', 'middle', 'swing', 'like', "n't", 'care', 'took', 'big', 'chance', 'high', 'school', 'dance', 'missy', 'ready', 'play', "n't", 'foolin', "'", "'cause", 'knew', 'doin', "'", 'knowed', 'love', 'stay', 'told', 'walk', 'way', 'walk', 'way', 'walk', 'way', 'walk', 'way', 'walk', 'way', 'walk', 'way', 'walk', 'way', 'walk', 'way', 'gim', 'kiss', 'like', 'schoolgirl', 'sweetie', 'classy', 'kinda', 'sassy', 'little', 'skirt', "'s", 'climbin', "'", 'way', 'k
# ...

# %%
import pandas as pd
rap_word_df = pd.DataFrame(wordlist, columns = ["Word"])
rap_word_df["Frequency"] = wordfreq
rap_word_df = rap_word_df.drop_duplicates()
print(rap_word_df)
# Out:
#              Word  Frequency
# 0      backstroke          1
# 1           lover          7
# 2          always         28
# 3           hidin          1
# 4               '       1082
# ...           ...        ...
# 35147        pole          1
# 35164     balance          1
# 35252      tonite          1
# 35259        bend          4
# 35260         ova          4
#
# [6017 rows x 2 columns]

# %%
rap_word_df = rap_word_df[rap_word_df.Word !='\'' ]
rap_word_df = rap_word_df[rap_word_df.Word !='\'s' ]
rap_word_df = rap_word_df[rap_word_df.Word !='n\'t' ]
rap_word_df = rap_word_df[rap_word_df.Word !='\'m' ]
rap_word_df = rap_word_df[rap_word_df.Word !='\'ve' ]
rap_word_df = rap_word_df[rap_word_df.Word !='\'ll' ]
rap_word_df = rap_word_df[rap_word_df.Word !='\'re' ]

rap_word_df_sorted = rap_word_df.sort_values(by='Frequency', ascending=False)
rap_word_df_sorted.head(10)
# Out:
#       Word  Frequency
# 46    like        493
# 215    get        457
# 499    got        437
# 241   know        303
# 218   yeah        222
# 825     ya        221
# 1028    na        200
# 5303    la        191
# 284   back        175
# 826    see        164

# %%
import matplotlib.pyplot as plt
import numpy as np

rap_songs_length = len(lyrics_test_df_rap)

# Create an array that contains the frequency count of the top 10 words for the song's genre
word = ["like", "get", "got", "know", "yeah", "ya", "na", "la", "back", "see"]
frequency = [493/rap_songs_length, 457/rap_songs_length, 437/rap_songs_length, 303/rap_songs_length, 222/rap_songs_length, 221/rap_songs_length, 200/rap_songs_length, 191/rap_songs_length, 175/rap_songs_length, 164/rap_songs_length]

x_axis = np.arange(0, len(word))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)

plt.title("Avg Word Frequency for Genre: Rap")
plt.xlabel("Word in Song")
plt.ylabel("Word Frequency")

plt.xlim(-0.75, len(word)-.25)
plt.ylim(0, max(frequency) + .5)

plt.bar(x_axis, frequency, facecolor="red", alpha=0.75, align="center")
plt.xticks(tick_locations, word)

plt.savefig('rap_barchart.svg')
plt.savefig('rap_barchart.png')

# %% [markdown]
# # R&B Genre

# %%
# Making a new dataframe with only the rnb genre from our pivoted dataframe above and dropping any null values
lyrics_test_df_rnb = lyrics_test_df_pivot[['Rhythm and Blues']].dropna()
lyrics_test_df_rnb.head()

## this prints out the whole dataframe so you can view up to 999 rows
# with pd.option_context('display.max_rows', 999):
#     print (lyrics_test_df_rnb)
# Out:
# genre                                   Rhythm and Blues
# 363    i bet youre wondering how i knew bout youre pl...
# 364    hey mama dont you treat me wrong come and love...
# 365    come here sister papas in the swing he aint to...
# 366    get outta that bed wash your face and hands ge...
# 367    im gonna tell aunt mary about uncle john he cl...

# %%
# Combining our lists into one big list from the rnb genre list

from Models import worddata

rnb_list = []

for word in lyrics_test_df_rnb['Rhythm and Blues']:
    words = worddata.word_calcs(word).nostopwordlist()
    for item in words: 
        rnb_list.append(item)
# print(rnb_list) 

wordlist = []
wordfreq = []

for word in rnb_list:
    i= 0
    wordcount= 0
    wordlist.append(word)
    wordfreq.append(rnb_list.count(word))

print(wordlist)
print(wordfreq)
# Out:
# ['bet', 'youre', 'wondering', 'knew', 'bout', 'youre', 'plans', 'make', 'blue', 'guy', 'knew', 'two', 'us', 'guys', 'know', 'love', 'took', 'surprise', 'must', 'say', 'found', 'yesterday', 'dont', 'know', 'heard', 'grapevine', 'much', 'longer', 'would', 'mine', 'oh', 'heard', 'grapevine', 'oh', 'im', 'lose', 'mind', 'honey', 'honey', 'yeah', 'heard', 'grapevine', 'much', 'longer', 'would', 'mine', 'baby', 'know', 'man', 'aint', 'supposed', 'cry', 'tears', 'cant', 'hold', 'inside', 'losin', 'would', 'end', 'life', 'see', 'cause', 'mean', 'much', 'could', 'told', 'love', 'someone', 'else', 'instead', 'heard', 'grapevine', 'much', 'longer', 'would', 'mine', 'oh', 'heard', 'grapevine', 'im', 'lose', 'mind', 'honey', 'honey', 'well', 'heard', 'grapevine', 'much', 'longer', 'would', 'mine', 'baby', 'people', 'say', 'believe', 'half', 'see', 'son', 'none', 'hear', 'cant', 'help', 'bein', 'confused', 'true', 'please', 'tell', 'dear', 'plan', 'let', 'go', 'guy', 'loved', 'dont', 'know', 'hear
# ...

# %%
import pandas as pd
rnb_word_df = pd.DataFrame(wordlist, columns = ["Word"])
rnb_word_df["Frequency"] = wordfreq
rnb_word_df = rnb_word_df.drop_duplicates()
print(rnb_word_df)
# Out:
#             Word  Frequency
# 0            bet          2
# 1          youre        104
# 2      wondering          1
# 3           knew         10
# 4           bout         11
# ...          ...        ...
# 12639    dancers          1
# 12659     throne          1
# 12663      jerry          1
# 12669    squares          1
# 12674     voices          1
#
# [1992 rows x 2 columns]

# %%
rnb_word_df = rnb_word_df[rnb_word_df.Word !='\'' ]
rnb_word_df = rnb_word_df[rnb_word_df.Word !='\'s' ]
rnb_word_df = rnb_word_df[rnb_word_df.Word !='n\'t' ]
rnb_word_df = rnb_word_df[rnb_word_df.Word !='\'m' ]
rnb_word_df = rnb_word_df[rnb_word_df.Word !='\'ve' ]
rnb_word_df = rnb_word_df[rnb_word_df.Word !='\'ll' ]
rnb_word_df = rnb_word_df[rnb_word_df.Word !='\'re' ]

rnb_word_df_sorted = rnb_word_df.sort_values(by='Frequency', ascending=False)
rnb_word_df_sorted.head(10)
# Out:
#       Word  Frequency
# 15    love        273
# 34      im        199
# 30      oh        198
# 46    baby        186
# 39    yeah        154
# 182     na        150
# 641    get        147
# 22    dont        137
# 283    got        136
# 160  right        120

# %%
import matplotlib.pyplot as plt
import numpy as np

rnb_songs_length = len(lyrics_test_df_rnb)

# Create an array that contains the frequency count of the top 10 words for the song's genre
word = ["love", "im", "oh", "baby", "yeah", "na", "get", "dont", "got", "right"]
frequency = [273/rnb_songs_length, 199/rnb_songs_length, 198/rnb_songs_length, 186/rnb_songs_length, 154/rnb_songs_length, 150/rnb_songs_length, 147/rnb_songs_length, 137/rnb_songs_length, 136/rnb_songs_length, 120/rnb_songs_length]

x_axis = np.arange(0, len(word))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)

plt.title("Avg Word Frequency for Genre: R&B")
plt.xlabel("Word in Song")
plt.ylabel("Word Frequency")

plt.xlim(-0.75, len(word)-.25)
plt.ylim(0, max(frequency) + .5)

plt.bar(x_axis, frequency, facecolor="red", alpha=0.75, align="center")
plt.xticks(tick_locations, word)
plt.show()

plt.savefig('rnb_barchart.svg')
plt.savefig('rnb_barchart.png')

# %% [markdown]
# # Rock Genre

# %%
# Making a new dataframe with only the rock genre from our pivoted dataframe above and dropping any null values
lyrics_test_df_rock = lyrics_test_df_pivot[['Rock']].dropna()

lyrics_test_df_rock.head()

## this prints out the whole dataframe so you can view up to 999 rows
# with pd.option_context('display.max_rows', 999):
#     print (lyrics_test_df_rock)
# Out:
# genre                                               Rock
# 179    finished with my woman because she couldn't he...
# 180    load up on guns and bring your friends it's fu...
# 181    you need coolin' baby i'm not foolin' i'm gonn...
# 182    backstroker lover always hidin' 'neath the cov...
# 183    we all came out to montreux on the lake geneva...

# %%
# Combining our lists into one big list from the rock genre list

from Models import worddata

rock_list = []


for word in lyrics_test_df_rock['Rock']:
    words = worddata.word_calcs(word).nostopwordlist()
    for item in words: 
        rock_list.append(item)
# print(rock_list)

wordlist = []
wordfreq = []

for word in rock_list:
    i= 0
    wordcount= 0
    wordlist.append(word)
    wordfreq.append(rock_list.count(word))

print(wordlist)
print(wordfreq)
# Out:
# ['finished', 'woman', 'could', "n't", 'help', 'mind', 'people', 'think', "'m", 'insane', 'frowning', 'time', 'day', 'long', 'think', 'things', 'nothing', 'seems', 'satisfy', 'think', "'ll", 'lose', 'mind', "n't", 'find', 'something', 'pacify', 'help', 'occupy', 'brain', 'oh', 'yeah', 'need', 'someone', 'show', 'things', 'life', 'ca', "n't", 'find', 'ca', "n't", 'see', 'things', 'make', 'true', 'happiness', 'must', 'blind', 'make', 'joke', 'sigh', 'laugh', 'cry', 'happiness', 'feel', 'like', 'love', 'unreal', 'hear', 'words', 'telling', 'state', 'tell', 'enjoy', 'life', 'wish', 'could', "'s", 'late', 'load', 'guns', 'bring', 'friends', "'s", 'fun', 'lose', 'pretend', "'s", 'overbored', 'selfassured', 'oh', 'know', 'dirty', 'word', 'hello', 'hello', 'hello', 'low', 'hello', 'hello', 'hello', 'low', 'hello', 'hello', 'hello', 'low', 'hello', 'hello', 'hello', 'lights', "'s", 'less', 'dangerous', 'entertain', 'us', 'feel', 'stupid', 'contagious', 'entertain', 'us', 'mulatto', 'albino', '
# ...

# %%
import pandas as pd
rock_word_df = pd.DataFrame(wordlist, columns = ["Word"])
rock_word_df["Frequency"] = wordfreq
rock_word_df = rock_word_df.drop_duplicates()
print(rock_word_df)
# Out:
#             Word  Frequency
# 0       finished          1
# 1          woman          9
# 2          could         31
# 3            n't        360
# 4           help         14
# ...          ...        ...
# 12869      omaha          1
# 12885  detective          1
# 12897      dudes          1
# 12902  proceeded          1
# 12972       wooh          3
#
# [2025 rows x 2 columns]

# %%
rock_word_df = rock_word_df[rock_word_df.Word !='\'' ]
rock_word_df = rock_word_df[rock_word_df.Word !='\'s' ]
rock_word_df = rock_word_df[rock_word_df.Word !='n\'t' ]
rock_word_df = rock_word_df[rock_word_df.Word !='\'m' ]
rock_word_df = rock_word_df[rock_word_df.Word !='\'ve' ]
rock_word_df = rock_word_df[rock_word_df.Word !='\'ll' ]
rock_word_df = rock_word_df[rock_word_df.Word !='\'re' ]

rock_word_df_sorted = rock_word_df.sort_values(by='Frequency', ascending=False)
rock_word_df_sorted.head(10)
# Out:
#       Word  Frequency
# 57    love        220
# 226     na        181
# 510    got        176
# 31    yeah        138
# 82    know        134
# 30      oh        124
# 231    way        119
# 56    like        113
# 1087  rock        109
# 238   give        108

# %%
import matplotlib.pyplot as plt
import numpy as np

rock_songs_length = len(lyrics_test_df_rock)

# Create an array that contains the frequency count of the top 10 words for the song's genre
word = ["love", "na", "got", "yeah", "know", "oh", "way", "like", "rock", "give"]
frequency = [220/rock_songs_length, 181/rock_songs_length, 176/rock_songs_length, 138/rock_songs_length, 134/rock_songs_length, 124/rock_songs_length, 119/rock_songs_length, 113/rock_songs_length, 109/rock_songs_length, 108/rock_songs_length]

x_axis = np.arange(0, len(word))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)

plt.title("Avg Word Frequency for Genre: Rock")
plt.xlabel("Word in Song")
plt.ylabel("Word Frequency")

plt.xlim(-0.75, len(word)-.25)
plt.ylim(0, max(frequency) + .5)

plt.bar(x_axis, frequency, facecolor="red", alpha=0.75, align="center")
plt.xticks(tick_locations, word)

plt.savefig('rock_barchart.svg')
plt.savefig('rock_barchart.png')
