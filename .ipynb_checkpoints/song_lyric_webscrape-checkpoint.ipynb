# %%
from bs4 import BeautifulSoup
from splinter import Browser
from pprint import pprint
import pymongo
import pandas as pd
import requests
import time
import numpy as np

# %%
genres = ['christian', 'country-music', 'hip-hop-rap', 'rhythm-blues', 'rock']

top_christian_urls = []
top_country_urls = []
top_hiphop_urls = []
top_rnb_urls = []
top_rock_urls = []

executable_path = {'executable_path': 'chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

for genre in genres:
    
    url = f'http://www.songlyrics.com/news/top-genres/{genre}/'
    browser.visit(url)
    time.sleep(2)
    response = requests.get(url)
    
    soup = BeautifulSoup(response.text, 'html.parser')
    urls = soup.find_all('td')
    
    top_songs_list = []
    value = 0
    
    top_songs_list.append(urls)
    current_url = top_songs_list[0]
    split_urls = str(current_url).split('"')
        
    if genre == 'christian':

        for i in split_urls:

            value = value + 1
            row = 19 + value * 16

            if value < 100:
                top_christian_urls.append(split_urls[row])
            else:
                break
                
    elif genre == 'country-music':
        
        for i in split_urls:

            value = value + 1
            row = 19 + value * 16

            if value < 100:
                top_country_urls.append(split_urls[row])
            else:
                break
    
    elif genre == 'hip-hop-rap':
        
        for i in split_urls:

            value = value + 1
            row = 19 + value * 16

            if value < 100:
                top_hiphop_urls.append(split_urls[row])
            else:
                break
    
    elif genre == 'rhythm-blues':
        
        for i in split_urls:

            value = value + 1
            row = 19 + value * 16

            if value < 100:
                top_rnb_urls.append(split_urls[row])
            else:
                break
    
    elif genre == 'rock':
        
        for i in split_urls:

            value = value + 1
            row = 19 + value * 16

            if value < 100:
                top_rock_urls.append(split_urls[row])
            else:
                break
    
    else:
        break

# %%
top_christian_urls = [x for x in top_christian_urls if x != '']
top_country_urls = [x for x in top_country_urls if x != '']
top_hiphop_urls = [x for x in top_hiphop_urls if x != '']
top_rnb_urls = [x for x in top_rnb_urls if x != '']
top_rock_urls = [x for x in top_rock_urls if x != '']

# %%
christian_artists = []
christian_songs = []
christian_lyrics = []
christian_genre = []

executable_path = {'executable_path': 'chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

for christian_song_url in top_christian_urls:

    try:
        url = christian_song_url
        browser.visit(url)
        time.sleep(2)
        response = requests.get(url)
        time.sleep(2)
        soup = BeautifulSoup(response.text, 'html.parser')
        time.sleep(2)

        title = soup.find_all('div', class_='pagetitle')
        time.sleep(2)
        split_title = str(title).split('>')
        length_title = len(split_title[2])
        title_artist = str(split_title[2])[0:(length_title-11)]
        split_title_artist = str(title_artist).split(' - ')

        artist = split_title_artist[0]
        title = split_title_artist[1]

        lyrics = soup.find_all('p', class_='songLyricsV14 iComment-text')
        time.sleep(2)

        christian_lyrics.append(str(lyrics).lower())
        christian_artists.append(artist)
        christian_songs.append(title)
        christian_genre.append('Christian')

    except:
        pass

# %%
christian_lyric_df = pd.DataFrame({
    
    "genre": christian_genre,
    "artist":christian_artists, 
    "song": christian_songs, 
    "lyrics": christian_lyrics})

christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('<a class="__cf_email__" data-cfemail="20524f4e484f4e545a60574f524c444e45540e4154540e4e4554" href="/cdn-cgi/l/email-protection">emailÂ protected</a>','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('<span class="icomment" data-chunk-id="6346" href="http://www.songlyrics.com/annot-6346">','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('<span class="icomment" data-chunk-id="6047" href="http://www.songlyrics.com/annot-6047">','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('<p class="songlyricsv14 icomment-text" id="songlyricsdiv">','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('&amp;','and')
christian_lyric_df['artist'] = christian_lyric_df['artist'].str.replace('&amp;','and')
christian_lyric_df['song'] = christian_lyric_df['song'].str.replace('&amp;','and')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('\n',' ')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('\r','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('</p>','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('</span>','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('<br/>','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('’','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('(','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace(')','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('[','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace(']','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('*','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('.','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('chorus','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('2x','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('x2','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('repeat ','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('verse 1','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('verse 2','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('verse 3','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('outro','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('ending','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('â€~','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('Ã¢â‚¬~','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('â€½','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('â€','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('=','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace(':','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('-','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace(',','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('\'','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('!','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('?','')
christian_lyric_df['lyrics'] = christian_lyric_df['lyrics'].str.replace('  ',' ')

christian_lyric_df['lyrics'].replace('', np.nan, inplace=True)
christian_lyric_df.dropna(subset=['lyrics'], inplace=True)

christian_lyric_df

# %%
christian_lyric_df.to_csv(r'output/christian_lyrics.csv')

# %%
rock_artists = []
rock_songs = []
rock_lyrics = []
rock_genre = []

executable_path = {'executable_path': 'chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

for rock_song_url in top_rock_urls:

    try:
        url = rock_song_url
        browser.visit(url)
        time.sleep(2)
        response = requests.get(url)
        time.sleep(2)
        soup = BeautifulSoup(response.text, 'html.parser')
        time.sleep(2)

        title = soup.find_all('div', class_='pagetitle')
        time.sleep(2)
        split_title = str(title).split('>')
        length_title = len(split_title[2])
        title_artist = str(split_title[2])[0:(length_title-11)]
        split_title_artist = str(title_artist).split(' - ')

        artist = split_title_artist[0]
        title = split_title_artist[1]

        lyrics = soup.find_all('p', class_='songLyricsV14 iComment-text')
        time.sleep(2)

        rock_lyrics.append(str(lyrics).lower())
        rock_artists.append(artist)
        rock_songs.append(title)
        rock_genre.append('Rock')

    except:
        pass

# %%
rock_lyric_df = pd.DataFrame({
    
    "genre": rock_genre,
    "artist": rock_artists, 
    "song": rock_songs, 
    "lyrics": rock_lyrics})

rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('<a class="__cf_email__" data-cfemail="20524f4e484f4e545a60574f524c444e45540e4154540e4e4554" href="/cdn-cgi/l/email-protection">emailÂ protected</a>','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('<span class="icomment" data-chunk-id="6346" href="http://www.songlyrics.com/annot-6346">','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('<span class="icomment" data-chunk-id="6047" href="http://www.songlyrics.com/annot-6047">','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('<p class="songlyricsv14 icomment-text" id="songlyricsdiv">','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('&amp;','and')
rock_lyric_df['artist'] = rock_lyric_df['artist'].str.replace('&amp;','and')
rock_lyric_df['song'] = rock_lyric_df['song'].str.replace('&amp;','and')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('\n',' ')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('\r','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('</p>','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('</span>','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('<br/>','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('’','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('(','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace(')','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('[','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace(']','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('*','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('.','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('chorus','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('2x','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('x2','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('repeat ','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('verse 1','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('verse 2','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('verse 3','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('outro','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('ending','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('â€~','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('Ã¢â‚¬~','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('â€½','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('â€','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('=','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace(':','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('-','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace(',','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('!','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('?','')
rock_lyric_df['lyrics'] = rock_lyric_df['lyrics'].str.replace('  ',' ')

rock_lyric_df['lyrics'].replace('', np.nan, inplace=True)
rock_lyric_df.dropna(subset=['lyrics'], inplace=True)

rock_lyric_df
# Out:
#    genre               artist                              song  \
# 0   Rock        Black Sabbath                          Paranoid
# 1   Rock              Nirvana         Smells Like Teen Spirit .
# 2   Rock              Santana                  Whole Lotta Love
# 3   Rock            Aerosmith              Walk This Way [Live]
# 4   Rock          Deep Purple                Smoke On the Water
# ..   ...                  ...                               ...
# 89  Rock         The Darkness  I Believe in a Thing Called Love
# 90  Rock          Sammy Hagar                  I Can't Drive 55
# 91  Rock               Kansas              Carry on Wayward Son
# 92  Rock            Autograph                 Turn Up the Radio
# 93  Rock  Grand Funk Railroad            We're an American Band
#
#                                                lyrics
# 0   finished with my woman because she couldn't he...
# 1   load up on guns and bring your friends it's fu...
# 2   you need coolin' baby i'm not foolin' i'm gonn...
# 3   backstroker lover always hidin' 'neath the cov...
# 4   we all came out to montreux on the lake geneva...
# ..                                                ...
# 89  can't explain all the feelings that you're mak...
# 90  one foot on the brake and one on the gas hey w...
# 91  carry on my wayward son there'll be peace when...
# 92  ooh yeah turn it up come on i'm working hard y...
# 93  out on the road for forty days last night in l...
#
# [94 rows x 4 columns]

# %%
rock_lyric_df.to_csv(r'output/rock_lyrics.csv')

# %%
country_artists = []
country_songs = []
country_lyrics = []
country_genre = []

executable_path = {'executable_path': 'chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

for country_song_url in top_country_urls:

    try:
        url = country_song_url
        browser.visit(url)
        time.sleep(2)
        response = requests.get(url)
        time.sleep(2)
        soup = BeautifulSoup(response.text, 'html.parser')
        time.sleep(2)

        title = soup.find_all('div', class_='pagetitle')
        time.sleep(2)
        split_title = str(title).split('>')
        length_title = len(split_title[2])
        title_artist = str(split_title[2])[0:(length_title-11)]
        split_title_artist = str(title_artist).split(' - ')

        artist = split_title_artist[0]
        title = split_title_artist[1]

        lyrics = soup.find_all('p', class_='songLyricsV14 iComment-text')
        time.sleep(2)

        country_lyrics.append(str(lyrics).lower())
        country_artists.append(artist)
        country_songs.append(title)
        country_genre.append('Country')

    except:
        pass

# %%
country_lyric_df = pd.DataFrame({
    
    "genre": country_genre,
    "artist": country_artists, 
    "song": country_songs, 
    "lyrics": country_lyrics})

country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('<a class="__cf_email__" data-cfemail="20524f4e484f4e545a60574f524c444e45540e4154540e4e4554" href="/cdn-cgi/l/email-protection">emailÂ protected</a>','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('<span class="icomment" data-chunk-id="6346" href="http://www.songlyrics.com/annot-6346">','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('<span class="icomment" data-chunk-id="6047" href="http://www.songlyrics.com/annot-6047">','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('<p class="songlyricsv14 icomment-text" id="songlyricsdiv">','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('&amp;','and')
country_lyric_df['artist'] = country_lyric_df['artist'].str.replace('&amp;','and')
country_lyric_df['song'] = country_lyric_df['song'].str.replace('&amp;','and')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('\n',' ')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('\r','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('</p>','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('</span>','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('<br/>','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('’','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('(','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace(')','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('[','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace(']','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('*','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('.','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('chorus','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('2x','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('x2','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('repeat ','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('verse 1','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('verse 2','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('verse 3','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('outro','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('ending','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('â€~','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('Ã¢â‚¬~','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('â€½','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('â€','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('=','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace(':','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('-','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace(',','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('!','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('?','')
country_lyric_df['lyrics'] = country_lyric_df['lyrics'].str.replace('  ',' ')

country_lyric_df['lyrics'].replace('', np.nan, inplace=True)
country_lyric_df.dropna(subset=['lyrics'], inplace=True)

country_lyric_df
# Out:
#       genre                      artist  \
# 0   Country  The Original Carter Family
# 1   Country                 Bill Monroe
# 2   Country               Hank Williams
# 3   Country                 Eddy Arnold
# 4   Country                George Jones
# ..      ...                         ...
# 81  Country            Harry McClintock
# 82  Country     John Michael Montgomery
# 83  Country               Kenny Chesney
# 84  Country                Dolly Parton
# 85  Country                Hank Locklin
#
#                                         song  \
# 0   Can the Circle Be Unbroken (Bye and Bye)
# 1                      Blue Moon of Kentucky
# 2                I'm So Lonesome I Could Cry
# 3                     Make The World Go Away
# 4                He Stopped Loving Her Today
# ..                                       ...
# 81                   Big Rock Candy Mountain
# 82                                   I Swear
# 83                         How Forever Feels
# 84                                    Jolene
# 85                Please Help Me I'm Falling
#
#                                                lyrics
# 0   i was standing by the window on a dark and clo...
# 1   blue moon of kentucky keep on shinin' shine on...
# 2   hear that lonesome whippoorwill he sounds too ...
# 3   hank cochran make the world go away and get it...
# 4   he said i'll love you till i die she told him ...
# ..                                                ...
# 81  one evening as the sun went down and the jungl...
# 82  i see the questions in your eyes i know what's...
# 83  big orange ball sinkin' in the water toes in t...
# 84  dolly parton greatest hits jolene jolene jolen...
# 85  please help me i'm falling in love with you cl...
#
# [86 rows x 4 columns]

# %%
country_lyric_df.to_csv(r'output/country_lyrics.csv')

# %%
hiphop_artists = []
hiphop_songs = []
hiphop_lyrics = []
hiphop_genre = []

executable_path = {'executable_path': 'chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

for hiphop_song_url in top_hiphop_urls:

    try:
        url = hiphop_song_url
        browser.visit(url)
        time.sleep(2)
        response = requests.get(url)
        time.sleep(2)
        soup = BeautifulSoup(response.text, 'html.parser')
        time.sleep(2)

        title = soup.find_all('div', class_='pagetitle')
        time.sleep(2)
        split_title = str(title).split('>')
        length_title = len(split_title[2])
        title_artist = str(split_title[2])[0:(length_title-11)]
        split_title_artist = str(title_artist).split(' - ')

        artist = split_title_artist[0]
        title = split_title_artist[1]

        lyrics = soup.find_all('p', class_='songLyricsV14 iComment-text')
        time.sleep(2)

        hiphop_lyrics.append(str(lyrics).lower())
        hiphop_artists.append(artist)
        hiphop_songs.append(title)
        hiphop_genre.append('Hip Hop/Rap')

    except:
        pass

# %%
hiphop_lyric_df = pd.DataFrame({
    
    "genre": hiphop_genre,
    "artist": hiphop_artists, 
    "song": hiphop_songs, 
    "lyrics": hiphop_lyrics})

hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('<a class="__cf_email__" data-cfemail="20524f4e484f4e545a60574f524c444e45540e4154540e4e4554" href="/cdn-cgi/l/email-protection">emailÂ protected</a>','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('<span class="icomment" data-chunk-id="6346" href="http://www.songlyrics.com/annot-6346">','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('<span class="icomment" data-chunk-id="6047" href="http://www.songlyrics.com/annot-6047">','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('<p class="songlyricsv14 icomment-text" id="songlyricsdiv">','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('&amp;','and')
hiphop_lyric_df['artist'] = hiphop_lyric_df['artist'].str.replace('&amp;','and')
hiphop_lyric_df['song'] = hiphop_lyric_df['song'].str.replace('&amp;','and')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('\n',' ')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('\r','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('</p>','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('</span>','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('<br/>','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('’','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('(','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace(')','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('[','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace(']','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('*','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('.','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('chorus','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('2x','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('x2','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('repeat ','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('verse 1','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('verse 2','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('verse 3','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('outro','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('ending','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('â€~','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('Ã¢â‚¬~','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('â€½','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('â€','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('=','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace(':','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('-','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace(',','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('!','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('?','')
hiphop_lyric_df['lyrics'] = hiphop_lyric_df['lyrics'].str.replace('  ',' ')

hiphop_lyric_df['lyrics'].replace('', np.nan, inplace=True)
hiphop_lyric_df.dropna(subset=['lyrics'], inplace=True)

hiphop_lyric_df
# Out:
#           genre                          artist  \
# 0   Hip Hop/Rap                      Run D.M.C.
# 1   Hip Hop/Rap            The Notorious B.I.G.
# 2   Hip Hop/Rap                          DR DRE
# 3   Hip Hop/Rap                          N.W.A.
# 4   Hip Hop/Rap                     Salt-N-Pepa
# ..          ...                             ...
# 85  Hip Hop/Rap                         N.E.R.D
# 86  Hip Hop/Rap                        Warren G
# 87  Hip Hop/Rap                      Biz Markie
# 88  Hip Hop/Rap                             EVE
# 89  Hip Hop/Rap  Lil Jon and The East Side Boyz
#
#                                 song  \
# 0                      Walk This Way
# 1                              Juicy
# 2            Nuthin' But A 'G' Thang
# 3             Straight Outta Compton
# 4                            Push It
# ..                               ...
# 85                          Lapdance
# 86                          Regulate
# 87                     Just A Friend
# 88                  Who's That Girl?
# 89  Get Low Featuring Yin Yang Twins
#
#                                                lyrics
# 0   backstroke lover always hidin' 'neath the cove...
# 1   intro fuck all y'all hoes get a grip motherfuc...
# 2   one two three and to the fo' snoop doggy dogg ...
# 3   you are now about to witness the strength of s...
# 4   ah push it ah push it oooh baby baby baby baby...
# ..                                                ...
# 85  dirty dog i'm i'm a dirty dog i'm a dirty dog ...
# 86  regulators we regulate any stealing of his pro...
# 87  have you ever met a girl that you tried to dat...
# 88  yo yo yo they wanna know who's that girl la la...
# 89  3 6 9 damn she's fine hopin' she can sock it t...
#
# [90 rows x 4 columns]

# %%
hiphop_lyric_df.to_csv(r'output/hiphop_lyrics.csv')

# %%
rnb_artists = []
rnb_songs = []
rnb_lyrics = []
rnb_genre = []

executable_path = {'executable_path': 'chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

for rnb_song_url in top_rnb_urls:

    try:
        url = rnb_song_url
        browser.visit(url)
        time.sleep(2)
        response = requests.get(url)
        time.sleep(2)
        soup = BeautifulSoup(response.text, 'html.parser')
        time.sleep(2)

        title = soup.find_all('div', class_='pagetitle')
        time.sleep(2)
        split_title = str(title).split('>')
        length_title = len(split_title[2])
        title_artist = str(split_title[2])[0:(length_title-11)]
        split_title_artist = str(title_artist).split(' - ')

        artist = split_title_artist[0]
        title = split_title_artist[1]

        lyrics = soup.find_all('p', class_='songLyricsV14 iComment-text')
        time.sleep(2)

        rnb_lyrics.append(str(lyrics).lower())
        rnb_artists.append(artist)
        rnb_songs.append(title)
        rnb_genre.append('Rhythm and Blues')


    except:
        pass

# %%
rnb_lyric_df = pd.DataFrame({
    
    "genre": rnb_genre,
    "artist": rnb_artists, 
    "song": rnb_songs, 
    "lyrics": rnb_lyrics})

#spring cleaning
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('<a class="__cf_email__" data-cfemail="20524f4e484f4e545a60574f524c444e45540e4154540e4e4554" href="/cdn-cgi/l/email-protection">emailÂ protected</a>','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('<span class="icomment" data-chunk-id="6346" href="http://www.songlyrics.com/annot-6346">','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('<span class="icomment" data-chunk-id="6047" href="http://www.songlyrics.com/annot-6047">','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('<p class="songlyricsv14 icomment-text" id="songlyricsdiv">','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('&amp;','and')
rnb_lyric_df['artist'] = rnb_lyric_df['artist'].str.replace('&amp;','and')
rnb_lyric_df['song'] = rnb_lyric_df['song'].str.replace('&amp;','and')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('\n',' ')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('\r','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('</p>','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('</span>','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('<br/>','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('’','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('(','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace(')','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('[','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace(']','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('*','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('.','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('chorus','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('2x','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('x2','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('repeat ','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('verse 1','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('verse 2','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('verse 3','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('outro','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('ending','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('â€~','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('Ã¢â‚¬~','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('â€½','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('â€','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('=','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace(':','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('-','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace(',','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('\'','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('!','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('?','')
rnb_lyric_df['lyrics'] = rnb_lyric_df['lyrics'].str.replace('  ',' ')

rnb_lyric_df['lyrics'].replace('', np.nan, inplace=True)
rnb_lyric_df.dropna(subset=['lyrics'], inplace=True)

rnb_lyric_df
# Out:
#                genre                    artist  \
# 0   Rhythm and Blues               Marvin Gaye
# 1   Rhythm and Blues               Ray Charles
# 2   Rhythm and Blues               James Brown
# 3   Rhythm and Blues            Big Joe Turner
# 4   Rhythm and Blues            Little Richard
# ..               ...                       ...
# 85  Rhythm and Blues               James Brown
# 86  Rhythm and Blues              Brook Benton
# 87  Rhythm and Blues                  Al Green
# 88  Rhythm and Blues              Chuck Willis
# 89  Rhythm and Blues  Sly and The Family Stone
#
#                                 song  \
# 0   I Heard It Through The Grapevine
# 1                       What'd I Say
# 2         Papa's Got A Brand New Bag
# 3              Shake Rattle and Roll
# 4                    Long Tall Sally
# ..                               ...
# 85                        Cold Sweat
# 86            Rainy Night In Georgia
# 87              Take Me To the River
# 88                        C.C. Rider
# 89                Dance to the Music
#
#                                                lyrics
# 0   i bet youre wondering how i knew bout youre pl...
# 1   hey mama dont you treat me wrong come and love...
# 2   come here sister papas in the swing he aint to...
# 3   get outta that bed wash your face and hands ge...
# 4   im gonna tell aunt mary about uncle john he cl...
# ..                                                ...
# 85  ha i dont care ha about your past i just want ...
# 86  hoverin by my suitcase tryin to find a warm pl...
# 87  i dont know why i love you like i do after all...
# 88  c c rider elvis presley well now see c c rider...
# 89  cynthia get up and dance to the music get on u...
#
# [90 rows x 4 columns]

# %%
rnb_lyric_df.to_csv(r'output/rnb_lyrics.csv')

# %%
# Combine the data into a single dataset

christian_lyrics_df = pd.read_csv("output/christian_lyrics.csv")
country_lyrics_df = pd.read_csv("output/country_lyrics.csv")
hiphop_lyrics_df = pd.read_csv("output/hiphop_lyrics.csv")
rock_lyrics_df = pd.read_csv("output/rock_lyrics.csv")
rnb_lyrics_df = pd.read_csv("output/rnb_lyrics.csv")

combined_lyrics1 = pd.merge(christian_lyrics_df, country_lyrics_df, how='outer')
combined_lyrics2 = pd.merge(rock_lyrics_df, hiphop_lyrics_df, how='outer')
combined_lyrics3 = pd.merge(combined_lyrics1, combined_lyrics2, how='outer')
combined_lyrics = pd.merge(combined_lyrics3, rnb_lyrics_df, how='outer')

combined_lyrics = combined_lyrics[["genre", "artist", "song", "lyrics"]]

combined_lyrics.to_csv(r'combined_lyrics.csv')

# %%
combined_lyrics
# Out:
#      Unnamed: 0             genre                    artist  \
# 0             0         Christian            Glory Revealed
# 1             1         Christian            Caedmon's Call
# 2             2         Christian                   MercyMe
# 3             3         Christian               Aaron Shust
# 4             4         Christian          Michael W. Smith
# ..          ...               ...                       ...
# 448          85  Rhythm and Blues               James Brown
# 449          86  Rhythm and Blues              Brook Benton
# 450          87  Rhythm and Blues                  Al Green
# 451          88  Rhythm and Blues              Chuck Willis
# 452          89  Rhythm and Blues  Sly and The Family Stone
#
#                        song                                             lyrics
# 0             By His Wounds  glory revealed by his wounds he was pierced fo...
# 1            God of Wonders  lord of heaven and earth lord of all creation ...
# 2        I Can Only Imagine  i can only imagine what it will be like when i...
# 3          My Savior My God  i am not skilled to understand what god has wi...
# 4                   Breathe  this is the air i breathe this is the air i br...
# ..                      ...                                                ...
# 448              Cold Sweat  ha i dont care ha about your past i just want ...
# 449  Rainy Night In Georgia  hoverin by my suitcase tryin to find a warm pl...
# 450    Take Me To the River  i dont know why i love you like i do after all...
# 451              C.C. Rider  c c rider elvis presley well now see c c rider...
# 452      Dance to the Music  cynthia get up and dance to the music get on u...
#
# [453 rows x 5 columns]
